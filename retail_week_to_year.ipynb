# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline
# Out:
# C:\Users\ACER-PC\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#Loading Demographic & transactional Data

Demodata = pd.read_csv('hh_demographic.csv')
Trandata = pd.read_csv('transaction_data.csv')

# %%
Demodata.head()
# Out:
#   AGE_DESC MARITAL_STATUS_CODE INCOME_DESC HOMEOWNER_DESC      HH_COMP_DESC  \
# 0      65+                   A      35-49K      Homeowner  2 Adults No Kids
# 1    45-54                   A      50-74K      Homeowner  2 Adults No Kids
# 2    25-34                   U      25-34K        Unknown     2 Adults Kids
# 3    25-34                   U      75-99K      Homeowner     2 Adults Kids
# 4    45-54                   B      50-74K      Homeowner     Single Female
#
#   HOUSEHOLD_SIZE_DESC KID_CATEGORY_DESC  household_key
# 0                   2      None/Unknown              1
# 1                   2      None/Unknown              7
# 2                   3                 1              8
# 3                   4                 2             13
# 4                   1      None/Unknown             16

# %%
Trandata.head()
# Out:
#    household_key    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 0           2375  26984851472    1     1004906         1         1.39
# 1           2375  26984851472    1     1033142         1         0.82
# 2           2375  26984851472    1     1036325         1         0.99
# 3           2375  26984851472    1     1082185         1         1.21
# 4           2375  26984851472    1     8160430         1         1.50
#
#    STORE_ID  RETAIL_DISC  TRANS_TIME  WEEK_NO  COUPON_DISC  COUPON_MATCH_DISC
# 0       364        -0.60        1631        1          0.0                0.0
# 1       364         0.00        1631        1          0.0                0.0
# 2       364        -0.30        1631        1          0.0                0.0
# 3       364         0.00        1631        1          0.0                0.0
# 4       364        -0.39        1631        1          0.0                0.0

# %%
Trandata.drop(Trandata.columns[[1,2,3,4,6,7,8,10,11]], axis=1, inplace=True)

# %%
Trandata.head()
# Out:
#    household_key  SALES_VALUE  WEEK_NO
# 0           2375         1.39        1
# 1           2375         0.82        1
# 2           2375         0.99        1
# 3           2375         1.21        1
# 4           2375         1.50        1

# %%
# Joining of Demography data & transactional dataset

mergedata = pd.merge(Demodata,Trandata,on="household_key",how="left")

# %%
mergedata
# Out:
#         AGE_DESC MARITAL_STATUS_CODE INCOME_DESC HOMEOWNER_DESC  \
# 0            65+                   A      35-49K      Homeowner
# 1            65+                   A      35-49K      Homeowner
# 2            65+                   A      35-49K      Homeowner
# 3            65+                   A      35-49K      Homeowner
# 4            65+                   A      35-49K      Homeowner
# ...          ...                 ...         ...            ...
# 1427298    25-34                   U   Under 15K        Unknown
# 1427299    25-34                   U   Under 15K        Unknown
# 1427300    25-34                   U   Under 15K        Unknown
# 1427301    25-34                   U   Under 15K        Unknown
# 1427302    25-34                   U   Under 15K        Unknown
#
#              HH_COMP_DESC HOUSEHOLD_SIZE_DESC KID_CATEGORY_DESC  \
# 0        2 Adults No Kids                   2      None/Unknown
# 1        2 Adults No Kids                   2      None/Unknown
# ...

# %%
mergedata.drop(mergedata.columns[[0,1,2,3,4,5,6,7,8]], axis=1, inplace=True)

# %%
mergedata.tail()
# Out:
#          WEEK_NO
# 1427298      101
# 1427299      102
# 1427300      102
# 1427301      102
# 1427302      102

# %%
# Convert week to month

# %%
# Converting 

mergedatalist = mergedata.values.tolist()

# %%
type(mergedatalist)
# Out:
# list

# %%
# Converting week to year for transactional dataset 

weekdetails = [53]

def week_to_year(mergedatalist):
    for x in mergedatalist:
        if x < weekdetails:
            print("First Year")
        else:
           print("Second Year")

# %%
results = list(week_to_year(mergedatalist))

# %%
print(results)

# %%
print(mergedataFF)

# %%
mergedataFF = week_to_year(mergedatalist)

# %%
mergedataFF.values.tolist()

# %%
mergedataFF

# %%
from pandas import DataFrame

TrandataFinal = DataFrame(TrandatalistFF,columns=['Week_To_Year'])

# %%
TrandataFinal.tail()
